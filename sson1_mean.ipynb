# %% [markdown]
#         Importing Libraries

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from matplotlib import pyplot as plt
# import seaborn as sns

# %%
print('a')
# Out:
# a

# %% [markdown]
# Test commit - New line

# %% [markdown]
#         Loading stock data

# %%
ticker_start_date = "2010-01-01"
ticker_end_date = "2024-12-31"

apple_data1 = yf.download(
    tickers='AAPL', start=ticker_start_date, end=ticker_end_date, auto_adjust=False)
print(apple_data1.head())

print(apple_data1.columns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2010-01-04  6.418384  7.643214  7.660714  7.585000  7.622500  493729600
# 2010-01-05  6.429481  7.656429  7.699643  7.616071  7.664286  601904800
# 2010-01-06  6.327212  7.534643  7.686786  7.526786  7.656429  552160000
# 2010-01-07  6.315513  7.520714  7.571429  7.466071  7.562500  477131200
# 2010-01-08  6.357501  7.570714  7.571429  7.466429  7.510714  447610800
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])
